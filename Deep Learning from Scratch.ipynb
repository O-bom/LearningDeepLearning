# %% [markdown]
# # 1장 Hello python

# %% [markdown]
# ## 1. Python script

# %%
# class 만들기
class Man:
    def __init__(self, name):
        self.name = name
        print("Initialized!")

    def hello(self):
        print("Hello " + self.name + "!")

    def goodbye(self):
        print("Good-bye " + self.name + "!")

m = Man("David")
m.hello()
m.goodbye()
# Out:
# Initialized!
# Hello David!
# Good-bye David!

# %% [markdown]
# ## 1.5 Numpy

# %%
# numpy
import numpy as np

# %%
A = np.array([[1,2],[3,4]])
print(A)
print(A.shape)
print("A의 타입 : ", A.dtype)
# Out:
# [[1 2]
#  [3 4]]
# (2, 2)
# A의 타입 :  int64

# %%
B = np.array([[3,0],[0,6]])
print(A+B)
print(A*B)
# Out:
# [[ 4  2]
#  [ 3 10]]
# [[ 3  0]
#  [ 0 24]]

# %%
X = np.array([[51,55],[14,19],[0,4]])
print(X)
print(X[0][0])
print(X[1][1])
print(X>15)
X[X>15]
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]
# 51
# 19
# [[ True  True]
#  [False  True]
#  [False False]]
# array([51, 55, 19])

# %%
for row in X:
    print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %%
X = X.flatten()
print(X)
X[np.array([0,2,4])]
# Out:
# [51 55 14 19  0  4]
# array([51, 14,  0])

# %% [markdown]
# ## 1.6 Matplotlib
# ### 1.6.1 단순한 그래프 그리기

# %%
# matplotlib
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1)
y = np.sin(x)

#그래프 그리기
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 1.6.2 pyplot의 기능

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

# 그래프 그리기
plt.plot(x, y1, label = "sin")
plt.plot(x, y2, linestyle = "--", label = "cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin&cos')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.6.3 이미지 표시하기

# %%
import matplotlib.pyplot as plt 
from matplotlib.image import imread
img = imread('Lenna.png')

plt.imshow(img)
plt.show()

# %% [markdown]
# # 2장 퍼셉트론
# ## 2.3 퍼셉트론 구현하기
# ### 2.3.1 간단한 구현

# %%
def AND(x1, x2):
    w1, w2, theta = 0.5, 0.5, 0.7
    tmp = x1*w1 + x2*w2
    if tmp <= theta:
        return 0
    elif tmp > theta:
        return 1
print(AND(0,0))
print(AND(0,1))
print(AND(1,0))
print(AND(1,1))
# Out:
# 0
# 0
# 0
# 1

# %% [markdown]
# ### 2.3.2 가중치와 편향

# %%
import numpy as np
x = np.array([0,1])
w = np.array([0.5,0.5])
b = -0.7
print(w*x)
print(np.sum(w*x))
print(np.sum(w*x)+b)
# Out:
# [0.  0.5]
# 0.5
# -0.19999999999999996

# %% [markdown]
# ### 2.3.3 논리회로에 가중치와 편향 도입

# %%
def AND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.7
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else :
        return 1
print(AND(0,0))
print(AND(0,1))
print(AND(1,0))
print(AND(1,1))
# Out:
# 0
# 0
# 0
# 1

# %%
def NAND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([-0.5, -0.5])
    b = 0.7
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else :
        return 1
print(NAND(0,0))
print(NAND(0,1))
print(NAND(1,0))
print(NAND(1,1))
# Out:
# 1
# 1
# 1
# 0

# %%
def OR(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.2
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else :
        return 1
print(OR(0,0))
print(OR(0,1))
print(OR(1,0))
print(OR(1,1))
# Out:
# 0
# 1
# 1
# 1

# %% [markdown]
# ## 2.5 다층 퍼셉트론 구현
# ### 2.5.2 XOR 게이트 구현

# %%
# def XOR(x1, x2):
#     x = np.array(AND(OR(x1, x2),NAND(x1,x2)))
#     if x <= 0:
#         return 0
#     else :
#         return 1
# print(XOR(0,0))
# print(XOR(0,1))
# print(XOR(1,0))
# print(XOR(1,1))
def XOR (x1, x2):
    s1 = NAND(x1, x2)
    s2 = OR(x1, x2)
    y = AND(s1, s2)
    return y
print(XOR(0,0))
print(XOR(0,1))
print(XOR(1,0))
print(XOR(1,1))
# Out:
# 0
# 1
# 1
# 0

# %% [markdown]
# ## 3장 신경망
# ### 3.2.2 계단 함수 구현하기

# %%
def step_function(x):
    if x > 0:
        return 1
    else :
        return 0

print(step_function(-1))
# Out:
# 0

# %%
# 넘파이 배열을 입력으로 받을 수 있는 함수
def step_function(x):
    y = x > 0
    return y.astype(np.int32)

import numpy as np
x = np.array([-1.0, 1.0, 2.0])
y = x > 0
print(step_function(y))
# Out:
# [0 1 1]

# %% [markdown]
# ### 3.2.3 계단 함수의 그래프

# %%
import numpy as np
import matplotlib.pylab as plt
def step_function(x):
    return np.array(x > 0, dtype=np.int64)
x = np.arange(-0.5, 5.0, 0.1)
y = step_function(x)
plt.plot(x, y)
plt.ylim(-0.1, 1.1)
plt.show()

# %% [markdown]
# ### 3.2.4 시그모이드 함수 구현하기

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
x = np.array([-1.0, 1.0, 2.0])
sigmoid(x)
# Out:
# array([0.26894142, 0.73105858, 0.88079708])

# %%
# 넘파이 배열 요소들은 자동으로 스칼라값과 각각 연산됨
t = np.array([1.0, 2.0, 3.0])
print(1.0/t) # 1 나누기 넘파이 배열
print(1.0+t) # 1 더하기 넘파이 배열
# Out:
# [1.         0.5        0.33333333]
# [2. 3. 4.]

# %%
x = np.arange(-5.0, 5.0, 0.1)
y = sigmoid(x)
plt.plot(x, y)
plt.ylim(-0.1, 1.1)
plt.show()

# %% [markdown]
# ### 3.2.7 ReLU 함수

# %%
def relu(x):
    return np.maximum(0,x)
y = relu(x)
plt.plot(x, y)
plt.plt.ylim(-0.1, 1.1)
plt.plt.xlim(-2, 2)
plt.show()

# %% [markdown]
# ### 3.3.1 다차원 배열

# %%
import numpy as np
A = np.array([1, 2, 3, 4])
print(A)
print(np.ndim(A)) # 차원 수 확인
print(A.shape) # 배열의 형상 (자료형 : 튜플)
print(A.shape[0])
B = np.array([[1, 2], [3, 4], [5, 6]])
print(B)
print("배열 B의 차원 수 : ", np.ndim(B))
print("배열 B의 형상 : ", B.shape)
# Out:
# [1 2 3 4]
# 1
# (4,)
# 4
# [[1 2]
#  [3 4]
#  [5 6]]
# 배열 B의 차원 수 :  2
# 배열 B의 형상 :  (3, 2)

# %% [markdown]
# ### 3.3.2 행렬의 내적(행렬 곱)

# %%
A = np.array([[1,2],[3,4]])
print(A.shape)
B = np.array([[5,6], [7,8]])
print(B.shape)
print("행렬 곱 : ", np.dot(A, B))
# Out:
# (2, 2)
# (2, 2)
# 행렬 곱 :  [[19 22]
#  [43 50]]

# %%
A = np.array([[1,2,3],[4,5,6]])
print(A.shape)
B = np.array([[1,2],[3,4],[5,6]])
print(B.shape)
print(np.dot(A, B))
# Out:
# (2, 3)
# (3, 2)
# [[22 28]
#  [49 64]]

# %% [markdown]
# C = np.array([[1,2],[3,4]])
# print(np.dot(A, C)) # 행렬 곱셈 연산을 위한 조건이 맞지 않아 오류

# %%
A = np.array([[1,2],[3,4]])
B = np.array([7,8])
np.dot(A,B)

# %% [markdown]
# ### 3.3.3 신경망의 내적

# %%
x = np.array([1,2])
w = np.array([[1,3,5],[2,4,6]])
y = np.dot(x, w)
print(y)

# %% [markdown]
# ## 3.4 3층 신경망 구현하기

# %% [markdown]
# ### 3.4.2 각 층의 신호전달 구현하기

# %%
x = np.array([1.0, 0.5])
w1 = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
b1 = np.array([0.1, 0.2, 0.3])

print(w1.shape)
print(x.shape)
print(b1.shape)

a1 = np.dot(x, w1)+b1
z1 = sigmoid(a1)

print(a1)
print("z1 :", z1)

w2 = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
b2 = np.array([0.1, 0.2])

print(z1.shape)
print(w2.shape)
print(b2.shape)
a2 = np.dot(z1, w2) + b2
z2 = sigmoid(a2)
print("z2 :", z2)

def identity_function(x) : 
    return x

w3 = np.array([[0.1, 0.3], [0.2, 0.4]])
b3 = np.array([0.1, 0.2])

a3 = np.dot(z2, w3) + b3
y = identity_function(a3)

print("y : ", y)
# Out:
# (2, 3)
# (2,)
# (3,)
# [0.3 0.7 1.1]
# z1 : [0.57444252 0.66818777 0.75026011]
# (3,)
# (3, 2)
# (2,)
# z2 : [0.62624937 0.7710107 ]
# y :  [0.31682708 0.69627909]

# %% [markdown]
# ### 3.4.3 구현 정리

# %%
def init_network():
    network = {}
    network['W1'] = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
    network['b1'] = np.array([0.1, 0.2, 0.3])
    network['W2'] = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
    network['b2'] = np.array([0.1, 0.2])
    network['W3'] = np.array([[0.1, 0.3], [0.2, 0.4]])
    network['b3'] = np.array([0.1, 0.2])

    return network

def forword(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    a1 = np.dot(x, W1) + b1
    z1 = sigmoid(a1)
    a2 = np.dot(z1, W2) + b2
    z2 = sigmoid(a2)
    a3 = np.dot(z2, W3) + b3
    y = identity_function(a3)

    return y

network = init_network()
x = np.array([1.0, 0.5])
y = forword(network, x)
print(y)
# Out:
# [0.31682708 0.69627909]

# %% [markdown]
# ## 3.5 출력층 설계하기
# ### 3.5.1 항등 함수와 소프트맥스 함수 구현하기

# %%
def softmax(a):
    exp_a = np.exp(a)
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a
    return y

# %% [markdown]
# ### 3.5.2 소프트 맥스 함수 구현시 주의점

# %%
import numpy as np
a = np.array([1010, 1000, 990])
print(np.exp(a) / np.sum(np.exp(a))) # 제대로 계산 되지 않음
c = np.max(a) # c = 배열의 최댓값
print(np.exp(a-c) / np.sum(np.exp(a-c))) # 최대값을 빼면 제대로 계산됨
# Out:
# [nan nan nan]
# [9.99954600e-01 4.53978686e-05 2.06106005e-09]
# C:\Users\Kiun Kim\AppData\Local\Temp\ipykernel_24684\29536872.py:3: RuntimeWarning: overflow encountered in exp
#   print(np.exp(a) / np.sum(np.exp(a))) # 제대로 계산 되지 않음
# C:\Users\Kiun Kim\AppData\Local\Temp\ipykernel_24684\29536872.py:3: RuntimeWarning: invalid value encountered in divide
#   print(np.exp(a) / np.sum(np.exp(a))) # 제대로 계산 되지 않음

# %%
# 제대로 구현한 소프트 맥스 함수
def softmax(a):
    c = np.max(a)
    exp_a = np.exp(a-c)
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a
    return y

# %%
a = np.array([0.3, 2.9, 4.0])
y = softmax(a)
print(y) # 각 출력값은 0과 1사이의 
print(np.sum(y)) # softmax 함수 출력값을 모두 합하면 1
# 신경망을 학습시킬 때는 출력층에 softmax 합수를 사용하지만 추론(실제 사용)시에는 소프트 맥스 함수를 생략함
# Out:
# [0.01821127 0.24519181 0.73659691]
# 1.0

# %%
#List 데이터 타입
l = [[1,2,3],[4,5,6]]
type(l)

# %%
#print를 사용하지 않으면 한 번에 한 리스트만 출력가능
l[0]
l[1]

# %%
print(l[0])
print(l[1])

# %%
print(l[0][0])
print(l[0][1])
print(l[0][2])

# %%
for i, a in enumerate(l) : 
    for j, b in enumerate(a) :
        print(l[i][j])
# a, b 변수는 리스트 안 값을 버리고 index만 가져오기 위한 변수

# %%
np.__version__

# %%
print(np.ndarray)
np.ndarray.__name__

# %%
type(np.ndarray.var)

# %%
# 1) np.array
# 1차원 배열
vec = np.array([1,2,3,4,5])
print(vec)

# %%
# 2차원 배열

# %%
mat = np.array([[10,20,30],[60,70,80]])
print(mat)

# %%
print("vec의 타입 :", type(vec))
print("mat의 타입 :", type(mat))

# %%
# 축의 개수 ndim, 크기 shape
print("mat의 축의 개수 :", mat.ndim)
print("mat의 크기 :", mat.shape)

# %%
# 2) ndarray의 초기화
# 모든 값이 0인 행렬 생성 : np.zeros()
zero_mat = np.zeros((2,3))
print(zero_mat)

# %%
# 모든 값이 1인 행렬 생성 : np.ones()
one_mat = np.ones((2,3))
print(one_mat)

# %%
# 모든 값이 특정 상수인 행렬 생성 : np.full()
same_value_mat = np.full((2,2),7)
print(same_value_mat)

# %%
# 대각선 값이 1이고 나머지가 0인 행렬 생성 : np.eye
eye_mat = np.eye(3)
print(eye_mat)

# %%
# 임의의 값으로 채워진 행렬 생성 : np.random.random()
random_mat = np.random.random((2,2))
print(random_mat)

# %%
# 3) np.arange
# 0부터 n-1까지의 값을 가지는 행렬 생성 : np.arange(n)
range_vec1 = np.arange(10)
print(range_vec1)

# n부터 m-1까지의 값을 o만큼의 간격으로 행렬 생성 : np.arange(n,m,o)
range_vec2 = np.arange(1,10,2)
print(range_vec2)

# %%
# 4) np.reshape
# 내부 데이터 변경하지 않으면서 배열의 구조 변경 : np.reshape(행,열))
reshape_mat = np.array(np.arange(1,31).reshape((3,10)))
print(reshape_mat)
